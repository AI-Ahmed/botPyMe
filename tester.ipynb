# %%
# Read all the libraries which we're going to use in our bot & Load Data
import os
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'

# Just disables the warning, doesn't take advantage of AVX/FMA to run faster
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

## Numpy is a matrices libraries
import numpy as np
from sklearn.utils import shuffle

## Import tensorflow for using Keras, instead.
import tensorflow as tf
from tensorflow.keras.models import  Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

## Import Natural Language Processing toolkit
import nltk
# nltk.download()    # for missing language interpretable
from nltk.stem import WordNetLemmatizer


physical_devices = tf.config.experimental.list_physical_devices('GPU')
print(f"Num GPUs Available: {len(physical_devices)}")
tf.config.experimental.set_memory_growth(physical_devices[0], True)

## Import jason files and pickles to read our training datasets
import json
import pickle

# create an instance from nltk
lemmatizer = WordNetLemmatizer()

# opens & read the intents JSON file dataset for data training
intents_file = open(os.path.abspath('intents.json')).read()
intents = json.loads(intents_file)

# %%
# Data pre-processing
words = []
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        # tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)        
        # adding document in the corpus
        documents.append((word, intent['tag']))
        # add the formula tag to the class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# --------------------------------------------------------------------------------------------------------------------------------------------------------------#
# Now, we're looking for reduce all the canonical words – so we can reduce the number of total words in our vocabulary.
# Lemmatization, is reducing duplicates words that are similar to each other. (e.g. play, playing, plays, played)
## lemmatize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore_letters]
words = sorted(list(set(words)))
## sort classes
classes = sorted(tuple(set(classes)))
## document = combination between patterns and intents
print(len(documents), "documents")
## classes = intents
print(len(classes), "classes", classes)
## words = all words, vocabulary
print(len(words), "unique lemmatize words", words)

pickle.dump(words, open(os.path.abspath('words.pkl'), 'wb'))
pickle.dump(classes, open(os.path.abspath('classes.pkl'), 'wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatize words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# Create the training data
training = []
# Create empty array for the output
output_zeros = np.zeros(len(classes)).astype(int)
# training set, bag of words for everysentence
for doc in documents:
    # initialize bag of words
    bag = []
    # list of tokenized words for the patterns – intents
    word_patterns = doc[0]
    # lemmatize each word – create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    # append in the bag of words array with 1, if the word is found in the current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)

    # output is a '0' for each tag, and '1' for current tag (for each pattern)
    output_row = list(output_zeros)   # we assigned the empty matrix to new variables to avoid the accumulation that caused by using global variable in the loop. 
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# # shuffle the features and make numpy array
shuffle(training)
training = np.asarray(training)

# create training and testing set. X – (a.k.a patterns, entities, words), Y – (a.k.a intents, classes)
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data is created!")
# Out:
# Training data is created!

# %%
# Build the deep neural network model
model = Sequential([
                    Dense(128, input_shape=(len(train_x[0]), ), activation='relu'),
                    Dropout(0.5), # reduce the model rate to 0.5 to reduce the overfitting
                    Dense(64, activation='relu'),
                    Dropout(0.5), # reduce the model rate to 0.5 to reduce the overfitting
                    Dense(len(train_y[0]), activation='softmax'),
            ]) 

# Initialize an optimizer
## Stochastic gradient descent (SGD) with Nesterov Accelerated Gradient gives good result and speed to the model
sgd_nag = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

# Start to compile the model to prepare the training dataset for the fitting process
model.compile(optimizer=sgd_nag, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Fitting or training the model
hist = model.fit(x=np.array(train_x), y=np.array(train_y) ,batch_size=10, epochs=200, verbose=2)
hist
# Out:
# Epoch 1/200
# 5/5 - 1s - loss: 2.2241 - accuracy: 0.1915
# Epoch 2/200
# 5/5 - 0s - loss: 2.2729 - accuracy: 0.0851
# Epoch 3/200
# 5/5 - 0s - loss: 2.2155 - accuracy: 0.1489
# Epoch 4/200
# 5/5 - 0s - loss: 2.1352 - accuracy: 0.2340
# Epoch 5/200
# 5/5 - 0s - loss: 2.1224 - accuracy: 0.2128
# Epoch 6/200
# 5/5 - 0s - loss: 2.1125 - accuracy: 0.1702
# Epoch 7/200
# 5/5 - 0s - loss: 2.0318 - accuracy: 0.2766
# Epoch 8/200
# 5/5 - 0s - loss: 2.0225 - accuracy: 0.2766
# Epoch 9/200
# 5/5 - 0s - loss: 1.9471 - accuracy: 0.5106
# Epoch 10/200
# 5/5 - 0s - loss: 1.8521 - accuracy: 0.4681
# Epoch 11/200
# 5/5 - 0s - loss: 1.7265 - accuracy: 0.4681
# Epoch 12/200
# 5/5 - 0s - loss: 1.7610 - accuracy: 0.5319
# Epoch 13/200
# 5/5 - 0s - loss: 1.7060 - accuracy: 0.4681
# Epoch 14/200
# 5/5 - 0s - loss: 1.7326 - accuracy: 0.4468
# Epoch 15/200
# 5/5 - 0s - loss: 1.5910 - accuracy: 0.5745
# Epoch 16/200
# 5/5 - 0s - loss: 1.5066 - accuracy: 0.6383
# Epoch 17/200
# 5/5 - 0s - loss: 1.4887 - accuracy: 0.5319
# Epoch 18/200
# 5/5 - 0s - loss: 1.2929 - accuracy: 0.7872
# Epoch 19/200
# 5/5 - 0s - loss: 1.2401 - accuracy: 0.7234
# Epoch 20/200
# 5/5 - 0s - loss: 1.1654 - accuracy: 0.6596
# Epoch 21/200
# 5/5 - 0s - loss: 1.2717 - accuracy: 0.6383
# Epoch 22/200
# 5/5 - 0s - loss: 1.2290 - accuracy: 0.6596
# Epoch 23/200
# 5/5 - 0s - loss: 1.0635 - accuracy: 0.7872
# Epoch 24/200
# 5/5 - 0s - loss: 0.8875 - accuracy: 0.8511
# Epoch 25/200
# 5/5 - 0s - loss: 0.9583 - accuracy: 0.7021
# Epoch 26/200
# 5/5 - 0s - loss: 1.0004 - accuracy: 0.7447
# Epoch 27/200
# 5/5 - 0s - loss: 0.9415 - accuracy: 0.7447
# Epoch 28/200
# 5/5 - 0s - loss: 0.7224 - accuracy: 0.8511
# Epoch 29/200
# 5/5 - 0s - loss: 0.8454 - accuracy: 0.7872
# Epoch 30/200
# 5/5 - 0s - loss: 0.7780 - accuracy: 0.8298
# Epoch 31/200
# 5/5 - 0s - loss: 0.6966 - accuracy: 0.8298
# Epoch 32/200
# 5/5 - 0s - loss: 0.7358 - accuracy: 0.7872
# Epoch 33/200
# 5/5 - 0s - loss: 0.5378 - accuracy: 0.8298
# Epoch 34/200
# 5/5 - 0s - loss: 0.7002 - accuracy: 0.8085
# Epoch 35/200
# 5/5 - 0s - loss: 0.5118 - accuracy: 0.9362
# Epoch 36/200
# 5/5 - 0s - loss: 0.6331 - accuracy: 0.8298
# Epoch 37/200
# 5/5 - 0s - loss: 0.6007 - accuracy: 0.8936
# Epoch 38/200
# 5/5 - 0s - loss: 0.4855 - accuracy: 0.8936
# Epoch 39/200
# 5/5 - 0s - loss: 0.6462 - accuracy: 0.8085
# Epoch 40/200
# 5/5 - 0s - loss: 0.5501 - accuracy: 0.8298
# Epoch 41/200
# 5/5 - 0s - loss: 0.4596 - accuracy: 0.8298
# Epoch 42/200
# 5/5 - 0s - loss: 0.3692 - accuracy: 0.9787
# Epoch 43/200
# 5/5 - 0s - loss: 0.3955 - accuracy: 0.9574
# Epoch 44/200
# 5/5 - 0s - loss: 0.6215 - accuracy: 0.8511
# Epoch 45/200
# 5/5 - 0s - loss: 0.3105 - accuracy: 0.9362
# Epoch 46/200
# 5/5 - 0s - loss: 0.2687 - accuracy: 0.9574
# Epoch 47/200
# 5/5 - 0s - loss: 0.3056 - accuracy: 0.9362
# Epoch 48/200
# 5/5 - 0s - loss: 0.3714 - accuracy: 0.9362
# Epoch 49/200
# 5/5 - 0s - loss: 0.3549 - accuracy: 0.9362
# Epoch 50/200
# 5/5 - 0s - loss: 0.2528 - accuracy: 0.9362
# Epoch 51/200
# 5/5 - 0s - loss: 0.3254 - accuracy: 0.9362
# Epoch 52/200
# 5/5 - 0s - loss: 0.2358 - accuracy: 0.9574
# Epoch 53/200
# 5/5 - 0s - loss: 0.3647 - accuracy: 0.8936
# Epoch 54/200
# 5/5 - 0s - loss: 0.3272 - accuracy: 0.9362
# Epoch 55/200
# 5/5 - 0s - loss: 0.2540 - accuracy: 0.9362
# Epoch 56/200
# 5/5 - 0s - loss: 0.3134 - accuracy: 0.9574
# Epoch 57/200
# 5/5 - 0s - loss: 0.2906 - accuracy: 0.9149
# Epoch 58/200
# 5/5 - 0s - loss: 0.3041 - accuracy: 0.9362
# Epoch 59/200
# 5/5 - 0s - loss: 0.1272 - accuracy: 1.0000
# Epoch 60/200
# 5/5 - 0s - loss: 0.2047 - accuracy: 0.9787
# Epoch 61/200
# 5/5 - 0s - loss: 0.2279 - accuracy: 0.9787
# Epoch 62/200
# 5/5 - 0s - loss: 0.1769 - accuracy: 0.9787
# Epoch 63/200
# 5/5 - 0s - loss: 0.1956 - accuracy: 0.9362
# Epoch 64/200
# 5/5 - 0s - loss: 0.1991 - accuracy: 0.9787
# Epoch 65/200
# 5/5 - 0s - loss: 0.1810 - accuracy: 0.9787
# Epoch 66/200
# 5/5 - 0s - loss: 0.2583 - accuracy: 0.9574
# Epoch 67/200
# 5/5 - 0s - loss: 0.1167 - accuracy: 0.9787
# Epoch 68/200
# 5/5 - 0s - loss: 0.1521 - accuracy: 0.9574
# Epoch 69/200
# 5/5 - 0s - loss: 0.1988 - accuracy: 0.9362
# Epoch 70/200
# 5/5 - 0s - loss: 0.1817 - accuracy: 0.9787
# Epoch 71/200
# 5/5 - 0s - loss: 0.1741 - accuracy: 0.9787
# Epoch 72/200
# 5/5 - 0s - loss: 0.1396 - accuracy: 0.9787
# Epoch 73/200
# 5/5 - 0s - loss: 0.1727 - accuracy: 0.9787
# Epoch 74/200
# 5/5 - 0s - loss: 0.1562 - accuracy: 0.9574
# Epoch 75/200
# 5/5 - 0s - loss: 0.1561 - accuracy: 0.9787
# Epoch 76/200
# 5/5 - 0s - loss: 0.1687 - accuracy: 0.9574
# Epoch 77/200
# 5/5 - 0s - loss: 0.1698 - accuracy: 0.9787
# Epoch 78/200
# 5/5 - 0s - loss: 0.1178 - accuracy: 1.0000
# Epoch 79/200
# 5/5 - 0s - loss: 0.2129 - accuracy: 0.9362
# Epoch 80/200
# 5/5 - 0s - loss: 0.2460 - accuracy: 0.9574
# Epoch 81/200
# 5/5 - 0s - loss: 0.1220 - accuracy: 1.0000
# Epoch 82/200
# 5/5 - 0s - loss: 0.1433 - accuracy: 0.9787
# Epoch 83/200
# 5/5 - 0s - loss: 0.1268 - accuracy: 0.9574
# Epoch 84/200
# 5/5 - 0s - loss: 0.1029 - accuracy: 1.0000
# Epoch 85/200
# 5/5 - 0s - loss: 0.1548 - accuracy: 0.9574
# Epoch 86/200
# 5/5 - 0s - loss: 0.1121 - accuracy: 1.0000
# Epoch 87/200
# 5/5 - 0s - loss: 0.0932 - accuracy: 1.0000
# Epoch 88/200
# 5/5 - 0s - loss: 0.1159 - accuracy: 0.9574
# Epoch 89/200
# 5/5 - 0s - loss: 0.1058 - accuracy: 0.9787
# Epoch 90/200
# 5/5 - 0s - loss: 0.1294 - accuracy: 0.9787
# Epoch 91/200
# 5/5 - 0s - loss: 0.0922 - accuracy: 1.0000
# Epoch 92/200
# 5/5 - 0s - loss: 0.1089 - accuracy: 1.0000
# Epoch 93/200
# 5/5 - 0s - loss: 0.0650 - accuracy: 1.0000
# Epoch 94/200
# 5/5 - 0s - loss: 0.0656 - accuracy: 1.0000
# Epoch 95/200
# 5/5 - 0s - loss: 0.1346 - accuracy: 0.9787
# Epoch 96/200
# 5/5 - 0s - loss: 0.1460 - accuracy: 0.9787
# Epoch 97/200
# 5/5 - 0s - loss: 0.0963 - accuracy: 0.9787
# Epoch 98/200
# 5/5 - 0s - loss: 0.0445 - accuracy: 1.0000
# Epoch 99/200
# 5/5 - 0s - loss: 0.1066 - accuracy: 1.0000
# Epoch 100/200
# 5/5 - 0s - loss: 0.0586 - accuracy: 1.0000
# Epoch 101/200
# 5/5 - 0s - loss: 0.0814 - accuracy: 0.9787
# Epoch 102/200
# 5/5 - 0s - loss: 0.1604 - accuracy: 0.9787
# Epoch 103/200
# 5/5 - 0s - loss: 0.0972 - accuracy: 0.9787
# Epoch 104/200
# 5/5 - 0s - loss: 0.0880 - accuracy: 0.9787
# Epoch 105/200
# 5/5 - 0s - loss: 0.1623 - accuracy: 0.9574
# Epoch 106/200
# 5/5 - 0s - loss: 0.0823 - accuracy: 0.9787
# Epoch 107/200
# 5/5 - 0s - loss: 0.0569 - accuracy: 0.9787
# Epoch 108/200
# 5/5 - 0s - loss: 0.1172 - accuracy: 0.9787
# Epoch 109/200
# 5/5 - 0s - loss: 0.1300 - accuracy: 0.9574
# Epoch 110/200
# 5/5 - 0s - loss: 0.2155 - accuracy: 0.8936
# Epoch 111/200
# 5/5 - 0s - loss: 0.1322 - accuracy: 0.9574
# Epoch 112/200
# 5/5 - 0s - loss: 0.0752 - accuracy: 1.0000
# Epoch 113/200
# 5/5 - 0s - loss: 0.0815 - accuracy: 0.9787
# Epoch 114/200
# 5/5 - 0s - loss: 0.1468 - accuracy: 0.9574
# Epoch 115/200
# 5/5 - 0s - loss: 0.1351 - accuracy: 0.9787
# Epoch 116/200
# 5/5 - 0s - loss: 0.0398 - accuracy: 1.0000
# Epoch 117/200
# 5/5 - 0s - loss: 0.0726 - accuracy: 1.0000
# Epoch 118/200
# 5/5 - 0s - loss: 0.0472 - accuracy: 1.0000
# Epoch 119/200
# 5/5 - 0s - loss: 0.0452 - accuracy: 1.0000
# Epoch 120/200
# 5/5 - 0s - loss: 0.0724 - accuracy: 0.9787
# Epoch 121/200
# 5/5 - 0s - loss: 0.0378 - accuracy: 1.0000
# Epoch 122/200
# 5/5 - 0s - loss: 0.1849 - accuracy: 0.9362
# Epoch 123/200
# 5/5 - 0s - loss: 0.0578 - accuracy: 1.0000
# Epoch 124/200
# 5/5 - 0s - loss: 0.0741 - accuracy: 1.0000
# Epoch 125/200
# 5/5 - 0s - loss: 0.0804 - accuracy: 0.9574
# Epoch 126/200
# 5/5 - 0s - loss: 0.0533 - accuracy: 1.0000
# Epoch 127/200
# 5/5 - 0s - loss: 0.0421 - accuracy: 1.0000
# Epoch 128/200
# 5/5 - 0s - loss: 0.0799 - accuracy: 0.9787
# Epoch 129/200
# 5/5 - 0s - loss: 0.0460 - accuracy: 1.0000
# Epoch 130/200
# 5/5 - 0s - loss: 0.0643 - accuracy: 0.9787
# Epoch 131/200
# 5/5 - 0s - loss: 0.1059 - accuracy: 0.9787
# Epoch 132/200
# 5/5 - 0s - loss: 0.0372 - accuracy: 1.0000
# Epoch 133/200
# 5/5 - 0s - loss: 0.1165 - accuracy: 0.9574
# Epoch 134/200
# 5/5 - 0s - loss: 0.0357 - accuracy: 1.0000
# Epoch 135/200
# 5/5 - 0s - loss: 0.0493 - accuracy: 1.0000
# Epoch 136/200
# 5/5 - 0s - loss: 0.0571 - accuracy: 0.9787
# Epoch 137/200
# 5/5 - 0s - loss: 0.0328 - accuracy: 1.0000
# Epoch 138/200
# 5/5 - 0s - loss: 0.0176 - accuracy: 1.0000
# Epoch 139/200
# 5/5 - 0s - loss: 0.0374 - accuracy: 1.0000
# Epoch 140/200
# 5/5 - 0s - loss: 0.0667 - accuracy: 0.9787
# Epoch 141/200
# 5/5 - 0s - loss: 0.0676 - accuracy: 1.0000
# Epoch 142/200
# 5/5 - 0s - loss: 0.0891 - accuracy: 1.0000
# Epoch 143/200
# 5/5 - 0s - loss: 0.0401 - accuracy: 1.0000
# Epoch 144/200
# 5/5 - 0s - loss: 0.0668 - accuracy: 0.9787
# Epoch 145/200
# 5/5 - 0s - loss: 0.0291 - accuracy: 1.0000
# Epoch 146/200
# 5/5 - 0s - loss: 0.0521 - accuracy: 1.0000
# Epoch 147/200
# 5/5 - 0s - loss: 0.0493 - accuracy: 1.0000
# Epoch 148/200
# 5/5 - 0s - loss: 0.0505 - accuracy: 1.0000
# Epoch 149/200
# 5/5 - 0s - loss: 0.1437 - accuracy: 0.9787
# Epoch 150/200
# 5/5 - 0s - loss: 0.0255 - accuracy: 1.0000
# Epoch 151/200
# 5/5 - 0s - loss: 0.0380 - accuracy: 1.0000
# Epoch 152/200
# 5/5 - 0s - loss: 0.1029 - accuracy: 0.9787
# Epoch 153/200
# 5/5 - 0s - loss: 0.0194 - accuracy: 1.0000
# Epoch 154/200
# 5/5 - 0s - loss: 0.0430 - accuracy: 1.0000
# Epoch 155/200
# 5/5 - 0s - loss: 0.1191 - accuracy: 0.9574
# Epoch 156/200
# 5/5 - 0s - loss: 0.0756 - accuracy: 0.9787
# Epoch 157/200
# 5/5 - 0s - loss: 0.0607 - accuracy: 0.9787
# Epoch 158/200
# 5/5 - 0s - loss: 0.0216 - accuracy: 1.0000
# Epoch 159/200
# 5/5 - 0s - loss: 0.0523 - accuracy: 0.9787
# Epoch 160/200
# 5/5 - 0s - loss: 0.1013 - accuracy: 0.9787
# Epoch 161/200
# 5/5 - 0s - loss: 0.0154 - accuracy: 1.0000
# Epoch 162/200
# 5/5 - 0s - loss: 0.1367 - accuracy: 0.9574
# Epoch 163/200
# 5/5 - 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 164/200
# 5/5 - 0s - loss: 0.0567 - accuracy: 0.9787
# Epoch 165/200
# 5/5 - 0s - loss: 0.0425 - accuracy: 1.0000
# Epoch 166/200
# 5/5 - 0s - loss: 0.0341 - accuracy: 1.0000
# Epoch 167/200
# 5/5 - 0s - loss: 0.0547 - accuracy: 0.9787
# Epoch 168/200
# 5/5 - 0s - loss: 0.0381 - accuracy: 1.0000
# Epoch 169/200
# 5/5 - 0s - loss: 0.0569 - accuracy: 0.9787
# Epoch 170/200
# 5/5 - 0s - loss: 0.0722 - accuracy: 0.9787
# Epoch 171/200
# 5/5 - 0s - loss: 0.0403 - accuracy: 0.9787
# Epoch 172/200
# 5/5 - 0s - loss: 0.0214 - accuracy: 1.0000
# Epoch 173/200
# 5/5 - 0s - loss: 0.0644 - accuracy: 0.9787
# Epoch 174/200
# 5/5 - 0s - loss: 0.0318 - accuracy: 1.0000
# Epoch 175/200
# 5/5 - 0s - loss: 0.0660 - accuracy: 1.0000
# Epoch 176/200
# 5/5 - 0s - loss: 0.0420 - accuracy: 1.0000
# Epoch 177/200
# 5/5 - 0s - loss: 0.0335 - accuracy: 1.0000
# Epoch 178/200
# 5/5 - 0s - loss: 0.0560 - accuracy: 1.0000
# Epoch 179/200
# 5/5 - 0s - loss: 0.0433 - accuracy: 0.9787
# Epoch 180/200
# 5/5 - 0s - loss: 0.0449 - accuracy: 0.9787
# Epoch 181/200
# 5/5 - 0s - loss: 0.0596 - accuracy: 0.9787
# Epoch 182/200
# 5/5 - 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 183/200
# 5/5 - 0s - loss: 0.0558 - accuracy: 0.9787
# Epoch 184/200
# 5/5 - 0s - loss: 0.0375 - accuracy: 1.0000
# Epoch 185/200
# 5/5 - 0s - loss: 0.0243 - accuracy: 1.0000
# Epoch 186/200
# 5/5 - 0s - loss: 0.0230 - accuracy: 1.0000
# Epoch 187/200
# 5/5 - 0s - loss: 0.0349 - accuracy: 1.0000
# Epoch 188/200
# 5/5 - 0s - loss: 0.0432 - accuracy: 1.0000
# Epoch 189/200
# 5/5 - 0s - loss: 0.0380 - accuracy: 1.0000
# Epoch 190/200
# 5/5 - 0s - loss: 0.0333 - accuracy: 1.0000
# Epoch 191/200
# 5/5 - 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 192/200
# 5/5 - 0s - loss: 0.0133 - accuracy: 1.0000
# Epoch 193/200
# 5/5 - 0s - loss: 0.0434 - accuracy: 0.9787
# Epoch 194/200
# 5/5 - 0s - loss: 0.0161 - accuracy: 1.0000
# Epoch 195/200
# 5/5 - 0s - loss: 0.0274 - accuracy: 1.0000
# Epoch 196/200
# 5/5 - 0s - loss: 0.0176 - accuracy: 1.0000
# Epoch 197/200
# 5/5 - 0s - loss: 0.0463 - accuracy: 0.9787
# Epoch 198/200
# 5/5 - 0s - loss: 0.0820 - accuracy: 0.9787
# Epoch 199/200
# 5/5 - 0s - loss: 0.0359 - accuracy: 0.9787
# Epoch 200/200
# 5/5 - 0s - loss: 0.0162 - accuracy: 1.0000

# %%
# Saving the model
model.save(os.path.abspath('chatPyMe.h5'), hist)
print('Model Created!')
# Out:
# Model Created!
